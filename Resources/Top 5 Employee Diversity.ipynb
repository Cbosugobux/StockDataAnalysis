# %%
# Import the necessary library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the 2017 data file into a DataFrame
df2017 = pd.read_excel('Resources/Top 5 Employee Diversity.xlsx', sheet_name='2017')

# Clean data by replacing zeros as NaN
df2017.replace(0, np.nan, inplace=True)

df2017.head(10)
# Out:
#              Company  Female %  Male %  % White  % Asian  % Latino  % Black  \
# 0              Apple        32      68       54       21        13        9
# 1             Nvidia        17      83       37       45         3        1
# 2          Microsoft        26      74       56       31         6        4
# 3             Amazon        39      61       48       13        13       21
# 4  Google (Alphabet)        31      69       56       35         4        2
#
#    % Multi  % Other
# 0      3.0      1.0
# 1     14.0      NaN
# 2      2.0      NaN
# 3      NaN      5.0
# 4      4.0      1.0

# %%
# Plotting the bar chart for Female %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2017['Company'], df2017['Female %'], color='lightcoral')
plt.title('2017 Female Employee % by Top 5 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Female %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2017 Female % by Top 5.png")
plt.show()

# %%
# Plotting the bar chart for Asian %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2017['Company'], df2017['% Asian'], color='lightblue')
plt.title('2017 Asian Employee % by Top 5 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Asian %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2017 Asian % by Top 5.png")
plt.show()

# %%
# Plotting the bar chart for Black %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2017['Company'], df2017['% Black'], color='violet')
plt.title('2017 Black Employee % by Top 5 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Black %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2017 Black % by Top 5.png")
plt.show()

# %%
# Plotting the bar chart for Latino %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2017['Company'], df2017['% Latino'], color='gold')
plt.title('2017 Latino Employee % by Top 5 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Latino %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2017 Latino % by Top 5.png")
plt.show()

# %%
# Load the 2021 data file into a DataFrame
df2021 = pd.read_excel('Resources/Top 5 Employee Diversity.xlsx', sheet_name='2021')

# Clean data by replacing zeros as NaN
df2021.replace(0, np.nan, inplace=True)

df2021.head(10)
# Out:
#              Company  Female %  Male %  % White  % Asian  % Latino  % Black  \
# 0              Apple      34.8    65.2     43.8     27.9      14.8      9.4
# 1             Nvidia      19.1    80.3     38.3     47.5       3.3      2.5
# 2          Microsoft      29.7    70.3     48.6     35.6       7.0      5.7
# 3             Amazon      44.3    55.6     30.7     13.5      23.6     28.6
# 4  Google (Alphabet)      32.5    67.5     50.4     42.3       6.4      4.4
#
#    % Multi  % Other
# 0      3.2      0.7
# 1      1.1      NaN
# 2      2.5      0.5
# 3      2.6      1.7
# 4      NaN      0.8

# %%
# Plotting the bar chart for Female %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2021['Company'], df2021['Female %'], color='lightcoral')
plt.title('2021 Female Employee % by Top 10 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Female %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2021 Female % by Top 5.png")
plt.show()

# %%
# Plotting the bar chart for Asian %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2021['Company'], df2021['% Asian'], color='lightblue')
plt.title('2021 Asian Employee % by Top 10 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Asian %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2021 Asian % by Top 5.png")
plt.show()

# %%
# Plotting the bar chart for Black %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2021['Company'], df2021['% Black'], color='violet')
plt.title('2021 Black Employee % by Top 10 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Black %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2021 Black % by Top 5.png")
plt.show()

# %%
# Plotting the bar chart for Latino %
plt.figure(figsize=(10, 6))
bars = plt.bar(df2021['Company'], df2021['% Latino'], color='gold')
plt.title('2021 Latino Employee % by Top 10 US Tech Companies')
plt.xlabel('Company')
plt.ylabel('Latino %')
plt.xticks(rotation=45)

# Adding percentage values on top of the bars
for bar in bars:
    yval = bar.get_height()
    if not pd.isna(yval):  # Check for NaN values
        plt.text(bar.get_x() + bar.get_width() / 2.0, yval, f'{yval:.0f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig("2021 Latino % by Top 5.png")
plt.show()
