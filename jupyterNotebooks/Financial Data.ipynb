# %%
import json
import pandas as pd
import matplotlib.pyplot as plt


trump_file_path = "../Data/Trump.json"
biden_file_path = "../Data/Biden.json"

with open(trump_file_path, "r") as f:
    trump_data = json.load(f)

with open(biden_file_path, "r") as f:
    biden_data = json.load(f)

trump_companiesUS = list(trump_data[0].keys())[:5]
trump_companiesOUS = list(trump_data[0].keys())[10:15]
biden_companiesUS = list(biden_data[0].keys())[:5]
biden_companiesOUS = list(biden_data[0].keys())[10:15]

def extract_stock_data(data, companies):
    stock_dict = {}
    for company in companies:
        stock_data = data[0][company]["Stock Data"]
        dates = [entry["Date"] for entry in stock_data]
        prices = [entry["Close"] for entry in stock_data]
        stock_dict[company] = pd.Series(prices, index=pd.to_datetime(dates))
    
    return pd.DataFrame(stock_dict)


trump_dfUS = extract_stock_data(trump_data, trump_companiesUS)
biden_dfUS = extract_stock_data(biden_data, biden_companiesUS)
trump_dfOUS = extract_stock_data(trump_data, trump_companiesOUS)
biden_dfOUS = extract_stock_data(biden_data, biden_companiesOUS)

plt.figure(figsize=(12, 6))
for company in trump_dfUS.columns:
    trump_dfUS[company].plot(label=company)
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Stock Closing Prices of Top 5 Domestic Tech Companies (Trump Administration)")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.savefig("Top 5 Domestic Tech Companies (Trump Administration).png")
plt.show()

plt.figure(figsize=(12, 6))
for company in biden_dfUS.columns:
    biden_dfUS[company].plot(label=company)

plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Stock Closing Prices of Top 5 Domestic Tech Companies (Biden Administration)")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.savefig("Top 5 Domestic Tech Companies (Biden Administration).png")
plt.show()

plt.figure(figsize=(12, 6))
for company in trump_dfOUS.columns:
    trump_dfOUS[company].plot(label=company)
ax = plt.gca()
ax.set_ylim([0, 200])
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Stock Closing Prices of Top 5 Foreign Tech Companies (Trump Administration)")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.savefig("Top 5 Foreign Tech Companies (Trump Administration).png")
plt.show()

plt.figure(figsize=(12, 6))
for company in biden_dfOUS.columns:
    biden_dfOUS[company].plot(label=company)
ax = plt.gca()
ax.set_ylim([0, 300])
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("Stock Closing Prices of Top 5 Foreign Tech Companies (Biden Administration)")
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.savefig("Top 5 Foreign Tech Companies (Biden Administration).png")
plt.show()

# %% [markdown]
# trumpdf

# %%
trump_dfOUS
# Out:
#                   TSM         SSNLF        ASML      TCEHY        BABA
# 2017-01-20  24.353594  9.217007e+29  112.693504  23.381807   92.769615
# 2017-01-23  24.564167  9.217007e+29  112.804283  23.519619   95.039131
# 2017-01-24  24.961018  1.032305e+30  113.155167  23.666618   97.955681
# 2017-01-25  25.357862  1.032305e+30  113.367531  23.997360  100.495590
# 2017-01-26  25.195887  1.032305e+30  111.844017  24.355667   99.230461
# ...               ...           ...         ...        ...         ...
# 2017-12-22  33.141991 -8.130178e+28  163.393707  48.089451  170.251465
# 2017-12-26  32.573307 -8.130178e+28  161.407471  47.932892  166.427109
# 2017-12-27  32.682045  9.644539e+27  162.293335  47.454021  167.045197
# 2017-12-28  33.233978  9.644539e+27  162.442551  47.794762  166.398148
# 2017-12-29  33.158714  9.644539e+27  162.088226  47.813175  166.523682
#
# [239 rows x 5 columns]

# %%
print(trump_data)
# Out:
# [{'AAPL': {'Company Name': 'Apple Inc.', 'Address': 'One Apple Park Way', 'City': 'Cupertino', 'State': 'CA', 'Country': 'United States', 'Date Range': '2017-01-20 to 2017-12-31', 'Stock Data': [{'Date': '2017-01-20', 'Close': 27.75282859802246}, {'Date': '2017-01-23', 'Close': 27.77133560180664}, {'Date': '2017-01-24', 'Close': 27.745893478393555}, {'Date': '2017-01-25', 'Close': 28.1876220703125}, {'Date': '2017-01-26', 'Close': 28.201507568359375}, {'Date': '2017-01-27', 'Close': 28.20380973815918}, {'Date': '2017-01-30', 'Close': 28.129806518554688}, {'Date': '2017-01-31', 'Close': 28.065052032470703}, {'Date': '2017-02-01', 'Close': 29.776470184326172}, {'Date': '2017-02-02', 'Close': 29.725589752197266}, {'Date': '2017-02-03', 'Close': 29.85279655456543}, {'Date': '2017-02-06', 'Close': 30.13263702392578}, {'Date': '2017-02-07', 'Close': 30.41941261291504}, {'Date': '2017-02-08', 'Close': 30.537363052368164}, {'Date': '2017-02-09', 'Close': 30.758028030395508}, {'Date': '2017-0
# ...
