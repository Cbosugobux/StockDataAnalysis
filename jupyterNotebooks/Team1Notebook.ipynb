# %%
#Team 1 Joint Notebook for Project 3

# %%
#pip install dash

# %%
from dash import Dash, dcc, html, Input, Output, ctx
import pandas as pd
import plotly.express as px
import pymongo
from pymongo import MongoClient

# %%
# Connect to MongoDB
#client = MongoClient("mongodb://localhost:27017/")
#db = client["Project3DB"]  # Your database name
#collection1 = db["Biden"]  # Your collection name

# Function to fetch stock data from MongoDB
#def get_stock_data():
    #data = list(collection1.find({}, {"_id": 0}))  # Exclude MongoDB's _id field
    
#df = pd.DataFrame(data)
    
# Ensure date column is formatted properly
#df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d")
#return df

# %%
df=pd.read_json('Data/Trump.json')
df.head()
# Out:
#                                                               Apple Inc.  \
# Market Cap                                                 3494440861696
# Address                {'Street': 'One Apple Park Way', 'City': 'Cupe...
# 2017-01-20_2017-12-31  [{'Date': '2017-01-20', 'Close': 27.7528324127...
#
#                                                       NVIDIA Corporation  \
# Market Cap                                                 3252272234496
# Address                {'Street': '2788 San Tomas Expressway', 'City'...
# 2017-01-20_2017-12-31  [{'Date': '2017-01-20', 'Close': 2.56216263771...
#
#                                                    Microsoft Corporation  \
# Market Cap                                                 3058636685312
# Address                {'Street': 'One Microsoft Way', 'City': 'Redmo...
# 2017-01-20_2017-12-31  [{'Date': '2017-01-20', 'Close': 56.8596191406...
#
#                                                         Amazon.com, Inc.  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.keys()
#
# NameError: name 'df' is not defined
